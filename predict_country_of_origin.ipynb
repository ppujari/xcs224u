# %%
import pandas as pd
import numpy as np
import spacy
import en_core_web_lg

import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix, ConfusionMatrixDisplay

# %%
data = pd.read_csv('./data/ds-project-train.csv',low_memory=False)

# %%
data.shape
# Out:
# (143280, 30)

# %%
data.head()
# Out:
#    Unnamed: 0 SHIPPER SHIPPER.ADDRESS        CONSIGNEE CONSIGNEE.ADDRESS  \
# 0           1     NaN             NaN  -NOT AVAILABLE-               NaN
# 1           3     NaN             NaN  -NOT AVAILABLE-               NaN
# 2           6     NaN             NaN  -NOT AVAILABLE-               NaN
# 3           7     NaN             NaN  -NOT AVAILABLE-               NaN
# 4           8     NaN             NaN  -NOT AVAILABLE-               NaN
#
#   ZIPCODE NOTIFY NOTIFY.ADDRESS BILL.OF.LADING ARRIVAL.DATE  ...  \
# 0       0    NaN            NaN  CMDUSZ2359136   09/20/2012  ...
# 1       0    NaN            NaN  CMDUSZ2359139   09/20/2012  ...
# 2       0    NaN            NaN  CMDUSZ2359147   09/20/2012  ...
# 3       0    NaN            NaN  CMDUSZ2359149   09/20/2012  ...
# 4       0    NaN            NaN  CMDUSZ2359150   09/20/2012  ...
#
#                                      PRODUCT.DETAILS  \
# 0  PALLET SKIRTPALLET SKIRT FOR ITEM 948734PURCHA...
# 1  AIR HOGS HELI CAGE ASTAIR HOGS HELI CAGE ASTP....
# 2  BLACK FLAT PANEL TV MOUNTBLACK FLAT PANEL TV M...
# 3  ON-WALL GLASS SHELFON-WALL GLASS SHELFP.O.NO.:...
# 4  8PCS CONDIMENT SET WITH MDFLAZY SUSAN8PCS COND...
#
#                                    MARKS.AND.NUMBERS COUNTRY.OF.ORIGIN  \
# 0  DISTRIBUTED BY SAM-S WEST,INC. BENTONVILLE, AR...             China
# 1  TO: WAL-MART CASE IDENTIFICATI ON NUMBER US DE...             China
# 2  TO WAL-MART USA DEPT 00072 PO 9352743173 ITEM ...             China
# 3  TO WAL-MART USA DEPT 00072 PO 9352742880 ITEM ...             China
# 4  SWC P.O. 4895633105 CATEGORY 00014 SWC ITEM 63...             China
#
#    DISTRIBUTION.PORT CARRIER.CODE                      CARRIER.NAME  \
# 0                NaN         CMDU  COMPAGNIE MARITIME D-AFFRETEMENT
# 1                NaN         CMDU  COMPAGNIE MARITIME D-AFFRETEMENT
# 2                NaN         CMDU  COMPAGNIE MARITIME D-AFFRETEMENT
# 3                NaN         CMDU  COMPAGNIE MARITIME D-AFFRETEMENT
# 4                NaN         CMDU  COMPAGNIE MARITIME D-AFFRETEMENT
#
#        CARRIER.ADDRESS CARRIER.CITY CARRIER.STATE  CARRIER.ZIP
# 0  5701 LAKE WRIGHT DR      NORFOLK            VA        23502
# 1  5701 LAKE WRIGHT DR      NORFOLK            VA        23502
# 2  5701 LAKE WRIGHT DR      NORFOLK            VA        23502
# 3  5701 LAKE WRIGHT DR      NORFOLK            VA        23502
# 4  5701 LAKE WRIGHT DR      NORFOLK            VA        23502
#
# [5 rows x 30 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'SHIPPER', 'SHIPPER.ADDRESS', 'CONSIGNEE',
#        'CONSIGNEE.ADDRESS', 'ZIPCODE', 'NOTIFY', 'NOTIFY.ADDRESS',
#        'BILL.OF.LADING', 'ARRIVAL.DATE', 'WEIGHT..LB.', 'WEIGHT..KG.',
#        'US.PORT', 'QUANTITY', 'Q.UNIT', 'MEASUREMENT', 'M.UNIT',
#        'SHIP.REGISTERED.IN', 'VESSEL.NAME', 'CONTAINER.COUNT',
#        'PRODUCT.DETAILS', 'MARKS.AND.NUMBERS', 'COUNTRY.OF.ORIGIN',
#        'DISTRIBUTION.PORT', 'CARRIER.CODE', 'CARRIER.NAME', 'CARRIER.ADDRESS',
#        'CARRIER.CITY', 'CARRIER.STATE', 'CARRIER.ZIP'],
#       dtype='object')

# %%
#rename columns as it contains dot
data = data.rename(columns={'SHIPPER.ADDRESS': 'SHIPPER_ADDRESS', 'CONSIGNEE.ADDRESS': 'CONSIGNEE_ADDRESS'})
data = data.rename(columns={'NOTIFY.ADDRESS': 'NOTIFY_ADDRESS', 'BILL.OF.LADING': 'BILL_OF_LADING','ARRIVAL.DATE':'ARRIVAL_DATE'})
data = data.rename(columns={'WEIGHT..LB.': 'WEIGHT_LB', 'WEIGHT..KG.': 'WEIGHT_KG','US.PORT':'US_PORT','Q.UNIT':'Q_UNIT'})
data = data.rename(columns={'M.UNIT': 'M_UNIT', 'SHIP.REGISTERED.IN': 'SHIP_REGISTERED_IN','VESSEL.NAME':'VESSEL_NAME'})


data = data.rename(columns={'CONTAINER.COUNT': 'CONTAINER_COUNT', 'PRODUCT.DETAILS': 'PRODUCT_DETAILS','MARKS.AND.NUMBERS':'MARKS_AND_NUMBERS'})
data = data.rename(columns={'COUNTRY.OF.ORIGIN': 'COUNTRY_OF_ORIGIN', 'DISTRIBUTION.PORT': 'DISTRIBUTION_PORT','CARRIER.CODE':'CARRIER_CODE'})
data = data.rename(columns={'CARRIER.NAME': 'CARRIER_NAME', 'CARRIER.ADDRESS': 'CARRIER_ADDRESS','CARRIER.CITY':'CARRIER_CITY'})
data = data.rename(columns={'CARRIER.STATE': 'CARRIER_STATE', 'CARRIER.ZIP': 'CARRIER_ZIP'})
data = data.rename(columns={'PRODUCT.DETAILS': 'PRODUCT_DETAILS'})

# %%
#print(data['ENTITY'])

# %%
data.COUNTRY_OF_ORIGIN.unique()
# Out:
# array(['China', 'Hong Kong', 'Egypt', 'India', 'Malaysia', 'Pakistan',
#        'Thailand', 'Singapore', 'South Korea', 'Panama', 'Vietnam',
#        'China Taiwan', 'Brazil', 'Chile', 'Oman', 'Italy', 'Sri Lanka',
#        'Bahamas', 'Jamaica', 'Spain', 'Portugal', nan, 'Honduras',
#        'South Africa', 'United Kingdom', 'United Arab Em',
#        'Dominican Republic', 'Japan', 'Mexico', 'Netherlands',
#        'Costa Rica', 'Guatemala', 'Belgium', 'France', 'Israel',
#        'Unknown', 'Canada', 'Indonesia', 'Jordan', 'Germany', 'Colombia',
#        'New Zealand', 'Philippines', 'Turkey', 'Saudi Arabia', 'Iceland',
#        'Argentina', 'Sweden', 'Ecuador', 'US Virgin Is', 'Taiwan',
#        'Australia', 'Bermuda', 'Cayman Isl', 'Belize', 'Malta', 'Peru',
#        'Morocco', 'Greece', 'Guam', 'Romania', 'American Samoa',
#        'Cambodia', 'Haiti', 'Guadeloupe', 'Trinidad', 'Venezuela',
#        'Federal Republic of Germany', 'Neth Antilles', 'Denmark',
#        'Kuwait'], dtype=object)

# %%
#remove row which has country of origin is nan and Unknown
data.drop(data[data['COUNTRY_OF_ORIGIN'] == 'nan'].index, inplace = True)
data.drop(data[data['COUNTRY_OF_ORIGIN'] == 'Unknown'].index, inplace = True)
data.drop(data[data['COUNTRY_OF_ORIGIN'] == 'NaN'].index, inplace = True)

# %%
data.loc[data['COUNTRY_OF_ORIGIN']=='nan']
data = data.dropna()
data.COUNTRY_OF_ORIGIN.unique()
# Out:
# array(['China', 'Honduras', 'Pakistan', 'United Arab Em', 'India',
#        'Spain', 'Oman', 'Malaysia', 'Hong Kong', 'South Africa',
#        'Vietnam', 'Thailand', 'Singapore', 'Brazil', 'South Korea',
#        'Belgium', 'Sweden', 'Egypt', 'United Kingdom', 'Italy', 'Panama',
#        'China Taiwan', 'Japan', 'Jordan', 'Germany', 'Australia'],
#       dtype=object)

# %%
data.shape
# Out:
# (1453, 30)

# %%
nlp = spacy.load('en_core_web_lg')

data['ENTITY'] = data['PRODUCT_DETAILS'].apply(lambda x: list(nlp(x).ents))
#table = []
#for ent in doc.ents:
#    table.append([ent.text,ent.label_,spacy.explain(ent.label_)])
# Out:
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
feature_cols=['SHIPPER','SHIPPER_ADDRESS','CONSIGNEE','ZIPCODE','WEIGHT_LB',
             'US_PORT','SHIP_REGISTERED_IN','VESSEL_NAME', 'CONTAINER_COUNT',
              'DISTRIBUTION_PORT', 'CARRIER_CODE','COUNTRY_OF_ORIGIN']
df = data[feature_cols]

# %%
df.head()
# Out:
#                                   SHIPPER  \
# 9308    ACE INTERNATIONAL ELECTRONICS LTD
# 9623  AGROPECUARIA MONTELIBANO,S.A. DE C.
# 9629                AIR SEA TRANSPORT INC
# 9630                AIR SEA TRANSPORT INC
# 9650    AL KARAM TOWEL INDUSTRIES (PVT) L
#
#                                         SHIPPER_ADDRESS  \
# 9308  RILEY HOUSE, 88 LEI MUK ROAD KWAI CHUNG, NT UN...
# 9623  BARRIO LA CRUZ, CALLE PRINCIPAL SAN LORENZO,VA...
# 9629  3/F, GOLDSLAND BUILDING, NO.22-26 MINDEN AVENU...
# 9630  3/F, GOLDSLAND BUILDING, NO.22-26 MINDEN AVENU...
# 9650  D-11 D-11 SITE SUPER HIGHWAY SCHEME 33 KARACHI...
#
#                             CONSIGNEE ZIPCODE  WEIGHT_LB  \
# 9308            WAL-MART STORES, INC.   72716    65962.0
# 9623          ORCHARD HOUSE FOODS LTD   63872   126715.0
# 9629  AIR SEA TRANSPORT (CHICAGO) INC   60007    85948.0
# 9630  AIR SEA TRANSPORT (CHICAGO) INC   60007   115413.0
# 9650            WAL-MART CANADA CORP.       0   134337.0
#
#                                        US_PORT SHIP_REGISTERED_IN  \
# 9308                       Seattle, Washington            DENMARK
# 9623                         Norfolk, Virginia            GERMANY
# 9629                   Los Angeles, California            DENMARK
# 9630                   Los Angeles, California          SINGAPORE
# 9650  New York/Newark Area, Newark, New Jersey      UNITED STATES
#
#             VESSEL_NAME  CONTAINER_COUNT                DISTRIBUTION_PORT  \
# 9308  CLEMENTINE MAERSK              3.0                Chicago, Illinois
# 9623           ISLANDIA              3.0                Norfolk, Virginia
# 9629       METTE MAERSK              2.0  Dallas/Ft. Worth Airport, Texas
# 9630       MAERSK ALGOL              3.0  Dallas/Ft. Worth Airport, Texas
# 9650    MAERSK CAROLINA              6.0  Buffalo-Niagara Falls, New York
#
#      CARRIER_CODE COUNTRY_OF_ORIGIN
# 9308         MAEU             China
# 9623         MAEU          Honduras
# 9629         MAEU             China
# 9630         MAEU             China
# 9650         MAEU          Pakistan

# %%
DUMMY_PORT = pd.get_dummies(df['US_PORT'])
df = pd.merge(
    left=df,
    right=DUMMY_PORT,
    left_index=True,
    right_index=True,
)
df.drop('US_PORT', axis=1, inplace=True)
df.head()
# Out:
#                                   SHIPPER  \
# 9308    ACE INTERNATIONAL ELECTRONICS LTD
# 9623  AGROPECUARIA MONTELIBANO,S.A. DE C.
# 9629                AIR SEA TRANSPORT INC
# 9630                AIR SEA TRANSPORT INC
# 9650    AL KARAM TOWEL INDUSTRIES (PVT) L
#
#                                         SHIPPER_ADDRESS  \
# 9308  RILEY HOUSE, 88 LEI MUK ROAD KWAI CHUNG, NT UN...
# 9623  BARRIO LA CRUZ, CALLE PRINCIPAL SAN LORENZO,VA...
# 9629  3/F, GOLDSLAND BUILDING, NO.22-26 MINDEN AVENU...
# 9630  3/F, GOLDSLAND BUILDING, NO.22-26 MINDEN AVENU...
# 9650  D-11 D-11 SITE SUPER HIGHWAY SCHEME 33 KARACHI...
#
#                             CONSIGNEE ZIPCODE  WEIGHT_LB SHIP_REGISTERED_IN  \
# 9308            WAL-MART STORES, INC.   72716    65962.0            DENMARK
# 9623          ORCHARD HOUSE FOODS LTD   63872   126715.0            GERMANY
# 9629  AIR SEA TRANSPORT (CHICAGO) INC   60007    85948.0            DENMARK
# 9630  AIR SEA TRANSPORT (CHICAGO) INC   60007   115413.0          SINGAPORE
# 9650            WAL-MART CANADA CORP.       0   134337.0      UNITED STATES
#
#             VESSEL_NAME  CONTAINER_COUNT                DISTRIBUTION_PORT  \
# 9308  CLEMENTINE MAERSK              3.0                Chicago, Illinois
# 9623           ISLANDIA              3.0                Norfolk, Virginia
# 9629       METTE MAERSK              2.0  Dallas/Ft. Worth Airport, Texas
# 9630       MAERSK ALGOL              3.0  Dallas/Ft. Worth Airport, Texas
# 9650    MAERSK CAROLINA              6.0  Buffalo-Niagara Falls, New York
#
#      CARRIER_CODE  ... Houston, Texas  Long Beach, California  \
# 9308         MAEU  ...              0                       0
# 9623         MAEU  ...              0                       0
# 9629         MAEU  ...              0                       0
# 9630         MAEU  ...              0                       0
# 9650         MAEU  ...              0                       0
#
#       Los Angeles, California  Miami, Florida  \
# 9308                        0               0
# 9623                        0               0
# 9629                        1               0
# 9630                        1               0
# 9650                        0               0
#
#       New York/Newark Area, Newark, New Jersey  Norfolk, Virginia  \
# 9308                                         0                  0
# 9623                                         0                  1
# 9629                                         0                  0
# 9630                                         0                  0
# 9650                                         1                  0
#
#       Oakland, California  Philadelphia, Pennsylvania  Savannah, Georgia  \
# 9308                    0                           0                  0
# 9623                    0                           0                  0
# 9629                    0                           0                  0
# 9630                    0                           0                  0
# 9650                    0                           0                  0
#
#       Seattle, Washington
# 9308                    1
# 9623                    0
# 9629                    0
# 9630                    0
# 9650                    0
#
# [5 rows x 22 columns]

# %%
df['ZIPCODE'].unique()
# Out:
# array(['72716', '63872', '60007', '0', '21224', '10314', '1-209836',
#        '1-479273', '95376', '33014', '1-479277', '78044', '38672',
#        '19201', '72712', '30354', '1-978879', '1-7146801-978879', '1930',
#        '60191', '22210', '60056', '1-847228', '71330', '30297', '90220',
#        '41018', '77031', '92647', '1-212840', '1-416391', '1-503288',
#        '1-800308', '1-630810', '1-514685', '60433', '1-905673',
#        '1-514956', '1-859538', '1-416766', '1-514905', '1-310216',
#        '1-630307', '1-215922', '1-626281', '1-678553', '1-732640',
#        '1-757626', '90703', '1-786336', '33182', '90012', '90230',
#        '85282', '90670', '1-417823', '77042', '1-732283', '1-843554',
#        '1-206448', '1-516280', '11530', '68138', '60106', '38671',
#        '1-310469', '45241', '1-514420', '1-908704', '28273', '7102',
#        '1-416255', '30022', '37214', '1-404675', '42303', '40004',
#        '27101', '1-832295', '1-956727', '1-281582', '13124',
#        '1-2815821-281582', '91748', '1-626810', '77032',
#        '1-7136731-832295', '77060', '60085', '1-281372', '1-514288',
#        '1-2136131-832295', '1-6158551-832295', '1-9095941-832295',
#        '1-3109431-832295', '12002', '38141', '29418', '7201', '1-866447',
#        '1-852224', '78405', '1-5629081-832295', '1-281272', '75707'],
#       dtype=object)

# %%
df['WEIGHT_LB'] = df['WEIGHT_LB'].astype(float)
df['CONTAINER_COUNT'] = df['CONTAINER_COUNT'].astype(float)
#df['ZIPCODE']=df['ZIPCODE'].str.split('1-').str[0]
#df['ZIPCODE']=pd.to_numeric(df['ZIPCODE'])
#ZIP COde is a categorical

# %%
df.head()
# Out:
#                                   SHIPPER  \
# 9308    ACE INTERNATIONAL ELECTRONICS LTD
# 9623  AGROPECUARIA MONTELIBANO,S.A. DE C.
# 9629                AIR SEA TRANSPORT INC
# 9630                AIR SEA TRANSPORT INC
# 9650    AL KARAM TOWEL INDUSTRIES (PVT) L
#
#                                         SHIPPER_ADDRESS  \
# 9308  RILEY HOUSE, 88 LEI MUK ROAD KWAI CHUNG, NT UN...
# 9623  BARRIO LA CRUZ, CALLE PRINCIPAL SAN LORENZO,VA...
# 9629  3/F, GOLDSLAND BUILDING, NO.22-26 MINDEN AVENU...
# 9630  3/F, GOLDSLAND BUILDING, NO.22-26 MINDEN AVENU...
# 9650  D-11 D-11 SITE SUPER HIGHWAY SCHEME 33 KARACHI...
#
#                             CONSIGNEE ZIPCODE  WEIGHT_LB SHIP_REGISTERED_IN  \
# 9308            WAL-MART STORES, INC.   72716    65962.0            DENMARK
# 9623          ORCHARD HOUSE FOODS LTD   63872   126715.0            GERMANY
# 9629  AIR SEA TRANSPORT (CHICAGO) INC   60007    85948.0            DENMARK
# 9630  AIR SEA TRANSPORT (CHICAGO) INC   60007   115413.0          SINGAPORE
# 9650            WAL-MART CANADA CORP.       0   134337.0      UNITED STATES
#
#             VESSEL_NAME  CONTAINER_COUNT                DISTRIBUTION_PORT  \
# 9308  CLEMENTINE MAERSK              3.0                Chicago, Illinois
# 9623           ISLANDIA              3.0                Norfolk, Virginia
# 9629       METTE MAERSK              2.0  Dallas/Ft. Worth Airport, Texas
# 9630       MAERSK ALGOL              3.0  Dallas/Ft. Worth Airport, Texas
# 9650    MAERSK CAROLINA              6.0  Buffalo-Niagara Falls, New York
#
#      CARRIER_CODE  ... Houston, Texas  Long Beach, California  \
# 9308         MAEU  ...              0                       0
# 9623         MAEU  ...              0                       0
# 9629         MAEU  ...              0                       0
# 9630         MAEU  ...              0                       0
# 9650         MAEU  ...              0                       0
#
#       Los Angeles, California  Miami, Florida  \
# 9308                        0               0
# 9623                        0               0
# 9629                        1               0
# 9630                        1               0
# 9650                        0               0
#
#       New York/Newark Area, Newark, New Jersey  Norfolk, Virginia  \
# 9308                                         0                  0
# 9623                                         0                  1
# 9629                                         0                  0
# 9630                                         0                  0
# 9650                                         1                  0
#
#       Oakland, California  Philadelphia, Pennsylvania  Savannah, Georgia  \
# 9308                    0                           0                  0
# 9623                    0                           0                  0
# 9629                    0                           0                  0
# 9630                    0                           0                  0
# 9650                    0                           0                  0
#
#       Seattle, Washington
# 9308                    1
# 9623                    0
# 9629                    0
# 9630                    0
# 9650                    0
#
# [5 rows x 22 columns]

# %%
categorical=['SHIPPER','SHIPPER_ADDRESS','CONSIGNEE','SHIP_REGISTERED_IN','VESSEL_NAME','DISTRIBUTION_PORT','CARRIER_CODE','ZIPCODE','COUNTRY_OF_ORIGIN']

# %%
# Label encoding for categoricals
le = preprocessing.LabelEncoder()
for cat in categorical:
    df[cat] = le.fit_transform(df[cat])

# %%
df.head()
# Out:
#       SHIPPER  SHIPPER_ADDRESS  CONSIGNEE  ZIPCODE  WEIGHT_LB  \
# 9308        1              403        135       88    65962.0
# 9623        3              145         77       82   126715.0
# 9629        4               85          3       76    85948.0
# 9630        4               85          3       76   115413.0
# 9650        5              166        131        0   134337.0
#
#       SHIP_REGISTERED_IN  VESSEL_NAME  CONTAINER_COUNT  DISTRIBUTION_PORT  \
# 9308                   4           19              3.0                  7
# 9623                   6           54              3.0                 24
# 9629                   4          100              2.0                 10
# 9630                  13           61              3.0                 10
# 9650                  16           65              6.0                  3
#
#       CARRIER_CODE  ...  Houston, Texas  Long Beach, California  \
# 9308             4  ...               0                       0
# 9623             4  ...               0                       0
# 9629             4  ...               0                       0
# 9630             4  ...               0                       0
# 9650             4  ...               0                       0
#
#       Los Angeles, California  Miami, Florida  \
# 9308                        0               0
# 9623                        0               0
# 9629                        1               0
# 9630                        1               0
# 9650                        0               0
#
#       New York/Newark Area, Newark, New Jersey  Norfolk, Virginia  \
# 9308                                         0                  0
# 9623                                         0                  1
# 9629                                         0                  0
# 9630                                         0                  0
# 9650                                         1                  0
#
#       Oakland, California  Philadelphia, Pennsylvania  Savannah, Georgia  \
# 9308                    0                           0                  0
# 9623                    0                           0                  0
# 9629                    0                           0                  0
# 9630                    0                           0                  0
# 9650                    0                           0                  0
#
#       Seattle, Washington
# 9308                    1
# 9623                    0
# 9629                    0
# 9630                    0
# 9650                    0
#
# [5 rows x 22 columns]

# %%
df['WEIGHT_LB'] = df['WEIGHT_LB'].astype(float)

# %%
X = df.copy()
y = X.pop('COUNTRY_OF_ORIGIN')

# %%
X.head()
# Out:
#       SHIPPER  SHIPPER_ADDRESS  CONSIGNEE  ZIPCODE  WEIGHT_LB  \
# 9308        1              403        135       88    65962.0
# 9623        3              145         77       82   126715.0
# 9629        4               85          3       76    85948.0
# 9630        4               85          3       76   115413.0
# 9650        5              166        131        0   134337.0
#
#       SHIP_REGISTERED_IN  VESSEL_NAME  CONTAINER_COUNT  DISTRIBUTION_PORT  \
# 9308                   4           19              3.0                  7
# 9623                   6           54              3.0                 24
# 9629                   4          100              2.0                 10
# 9630                  13           61              3.0                 10
# 9650                  16           65              6.0                  3
#
#       CARRIER_CODE  ...  Houston, Texas  Long Beach, California  \
# 9308             4  ...               0                       0
# 9623             4  ...               0                       0
# 9629             4  ...               0                       0
# 9630             4  ...               0                       0
# 9650             4  ...               0                       0
#
#       Los Angeles, California  Miami, Florida  \
# 9308                        0               0
# 9623                        0               0
# 9629                        1               0
# 9630                        1               0
# 9650                        0               0
#
#       New York/Newark Area, Newark, New Jersey  Norfolk, Virginia  \
# 9308                                         0                  0
# 9623                                         0                  1
# 9629                                         0                  0
# 9630                                         0                  0
# 9650                                         1                  0
#
#       Oakland, California  Philadelphia, Pennsylvania  Savannah, Georgia  \
# 9308                    0                           0                  0
# 9623                    0                           0                  0
# 9629                    0                           0                  0
# 9630                    0                           0                  0
# 9650                    0                           0                  0
#
#       Seattle, Washington
# 9308                    1
# 9623                    0
# 9629                    0
# 9630                    0
# 9650                    0
#
# [5 rows x 21 columns]

# %%
svm = OneVsRestClassifier(LinearSVC(random_state=42))
X_train, X_test, y_train, y_test = train_test_split(
     X, y, train_size=0.80, test_size=0.20, random_state=42)
model = svm.fit(X_train,y_train)
# Out:
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred, normalize=False)
# Out:
# 36

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.93      0.14      0.25        97
#            6       0.00      0.00      0.00         0
#            8       0.00      0.00      0.00        13
#            9       0.00      0.00      0.00        16
#           10       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00        68
#           14       1.00      0.40      0.57        55
#           15       0.00      0.00      0.00         2
#           17       0.00      0.00      0.00         2
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         3
#           20       0.00      0.00      0.00        11
#           21       0.00      0.00      0.00         5
#           22       0.00      0.00      0.00         3
#           23       0.00      0.00      0.00         0
#           25       0.00      0.00      0.00        13
#
#     accuracy                           0.12       291
#    macro avg       0.11      0.03      0.05       291
# weighted avg       0.50      0.12      0.19       291
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/ppujari/Applications/anaconda3/envs/innovation_lab/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
xgb_model = xgb.XGBClassifier(objective="multi:softprob", random_state=42)
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

print(accuracy_score(y_test, y_pred))
# Out:
# 0.9209621993127147

# %%
X = df.copy()
y = X.pop('COUNTRY_OF_ORIGIN')
kfold = KFold(n_splits=4, shuffle=True, random_state=42)
for train_index, test_index in kfold.split(X):
    print(train_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    xgb_model = xgb.XGBClassifier(objective="multi:softprob",random_state=42)
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)

    print(accuracy_score(y_test, y_pred))

# %%
X = df.copy()
y = X.pop('COUNTRY_OF_ORIGIN')

# if more than one evaluation metric are given the last one is used for early stopping
xgb_model = xgb.XGBClassifier(objective="multi:softprob", random_state=42, eval_metric="auc")

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

xgb_model.fit(X_train, y_train, early_stopping_rounds=5, eval_set=[(X_test, y_test)])

y_pred = xgb_model.predict(X_test)

accuracy_score(y_test, y_pred)
